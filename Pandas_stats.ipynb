# %%
import pandas as pd
import os

DATA_PATHS = [
    '/Users/kishanterdal/Downloads/period_03/2024_fb_ads_president_scored_anon.csv',
    '/Users/kishanterdal/Downloads/period_03/2024_fb_posts_president_scored_anon.csv',
    '/Users/kishanterdal/Downloads/period_03/2024_tw_posts_president_scored_anon.csv'
]

def load_data(filepath):
    return pd.read_csv(filepath)

def overall_statistics(df, dataset_name):
    print(f"\n=== Overall Descriptive Statistics for {dataset_name} ===")
    for col in df.columns:
        print(f"\nColumn: {col}")
        print(df[col].describe())

    print("\nUnique Value Counts:")
    for col in df.columns:
        print(f"{col}: {df[col].nunique()}")

    print("\nMost Frequent Values:")
    for col in df.columns:
        if not df[col].mode().empty:
            print(f"{col}: {df[col].mode().iloc[0]}")

def group_statistics(df, group_cols, dataset_name):
    print(f"\n=== Grouped Statistics for {dataset_name} by {group_cols} ===")
    grouped = df.groupby(group_cols)

    for name, group in list(grouped)[0:3]:  # limit to first 3 groups
        print(f"\nGroup: {name}")
        print(group.describe(include='all'))

def analyze_dataset(filepath):
    if not os.path.isfile(filepath):
        print(f"File {filepath} does not exist. Skipping...")
        return

    df = load_data(filepath)
    dataset_name = os.path.basename(filepath)
    print(f"\nLoaded {df.shape[0]} rows and {df.shape[1]} columns from {dataset_name}")

    overall_statistics(df, dataset_name)

    columns = df.columns

    if 'page_id' in columns and 'ad_id' in columns:
        group_statistics(df, ['page_id', 'ad_id'], dataset_name)
    elif 'page_id' in columns:
        group_statistics(df, ['page_id'], dataset_name)
    elif 'state' in columns:
        group_statistics(df, ['state'], dataset_name)
    else:
        print(f"\nNo grouping columns ('page_id', 'ad_id', or 'state') found in {dataset_name}. Skipping grouping.")

def main():
    for filepath in DATA_PATHS:
        analyze_dataset(filepath)

if __name__ == "__main__":
    main()
# Out:
# Loaded 246745 rows and 41 columns from 2024_fb_ads_president_scored_anon.csv
#
# === Overall Descriptive Statistics for 2024_fb_ads_president_scored_anon.csv ===
#
# Column: page_id
# count                                                246745
# unique                                                 4475
# top       4d66f5853f0365dba032a87704a634f023d15babde973b...
# freq                                                  55503
# Name: page_id, dtype: object
#
# Column: ad_id
# count                                                246745
# unique                                               246745
# top       0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9...
# freq                                                      1
# Name: ad_id, dtype: object
#
# Column: ad_creation_time
# count         246745
# unique           547
# top       2024-10-27
# freq            8619
# Name: ad_creation_time, dtype: object
#
# Column: bylines
# count                   245736
# unique                    3790
# top       HARRIS FOR PRESIDENT
# freq                     49788
# Name: bylines, dtype: object
#
# Column: currency
# count     246745
# unique        18
# top          USD
# freq      246599
# Name: currency, dtype: object
#
# Column: delivery_by_region
# count     246745
# unique    141122
# top           {}
# freq       30989
# Name: delivery_by_region, dtype: object
#
# Column: demographic_distribution
# count     246745
# unique    215622
# top           {}
# freq       30989
# Name: demographic_distribution, dtype: object
#
# Column: estimated_audience_size
# count    2.467450e+05
# mean     5.564629e+05
# std      4.098648e+05
# min      0.000000e+00
# 25%      7.500000e+04
# 50%      3.000000e+05
# 75%      1.000001e+06
# max      1.000001e+06
# Name: estimated_audience_size, dtype: float64
#
# Column: estimated_impressions
# count     246745.000000
# mean       45601.525952
# std       136790.769901
# min          499.000000
# 25%          499.000000
# 50%         3499.000000
# 75%        22499.000000
# max      1000000.000000
# Name: estimated_impressions, dtype: float64
#
# Column: estimated_spend
# count    246745.000000
# mean       1061.291434
# std        4992.560749
# min          49.000000
# 25%          49.000000
# 50%          49.000000
# 75%         449.000000
# max      474999.000000
# Name: estimated_spend, dtype: float64
#
# Column: publisher_platforms
# count                        246745
# unique                            9
# top       ['facebook', 'instagram']
# freq                         214434
# Name: publisher_platforms, dtype: object
#
# Column: illuminating_scored_message
# count                                                246745
# unique                                                26338
# top       e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b93...
# freq                                                   5972
# Name: illuminating_scored_message, dtype: object
#
# Column: illuminating_mentions
# count     246745
# unique       278
# top           []
# freq       73205
# Name: illuminating_mentions, dtype: object
#
# Column: scam_illuminating
# count    246745.000000
# mean          0.071633
# std           0.257879
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: scam_illuminating, dtype: float64
#
# Column: election_integrity_Truth_illuminating
# count    246745.000000
# mean          0.050088
# std           0.218127
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: election_integrity_Truth_illuminating, dtype: float64
#
# Column: advocacy_msg_type_illuminating
# count    246745.000000
# mean          0.548631
# std           0.497630
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: advocacy_msg_type_illuminating, dtype: float64
#
# Column: issue_msg_type_illuminating
# count    246745.000000
# mean          0.381649
# std           0.485792
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: issue_msg_type_illuminating, dtype: float64
#
# Column: attack_msg_type_illuminating
# count    246745.000000
# mean          0.271856
# std           0.444917
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           1.000000
# Name: attack_msg_type_illuminating, dtype: float64
#
# Column: image_msg_type_illuminating
# count    246745.000000
# mean          0.222704
# std           0.416062
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: image_msg_type_illuminating, dtype: float64
#
# Column: cta_msg_type_illuminating
# count    246745.000000
# mean          0.572769
# std           0.494677
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
# Name: cta_msg_type_illuminating, dtype: float64
#
# Column: engagement_cta_subtype_illuminating
# count    246745.000000
# mean          0.124870
# std           0.330572
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: engagement_cta_subtype_illuminating, dtype: float64
#
# Column: fundraising_cta_subtype_illuminating
# count    246745.000000
# mean          0.228487
# std           0.419859
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: fundraising_cta_subtype_illuminating, dtype: float64
#
# Column: voting_cta_subtype_illuminating
# count    246745.000000
# mean          0.143845
# std           0.350933
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: voting_cta_subtype_illuminating, dtype: float64
#
# Column: covid_topic_illuminating
# count    246745.000000
# mean          0.024876
# std           0.155747
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: covid_topic_illuminating, dtype: float64
#
# Column: economy_topic_illuminating
# count    246745.000000
# mean          0.122122
# std           0.327427
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: economy_topic_illuminating, dtype: float64
#
# Column: education_topic_illuminating
# count    246745.000000
# mean          0.014327
# std           0.118833
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: education_topic_illuminating, dtype: float64
#
# Column: environment_topic_illuminating
# count    246745.000000
# mean          0.021249
# std           0.144212
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: environment_topic_illuminating, dtype: float64
#
# Column: foreign_policy_topic_illuminating
# count    246745.000000
# mean          0.005265
# std           0.072366
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: foreign_policy_topic_illuminating, dtype: float64
#
# Column: governance_topic_illuminating
# count    246745.000000
# mean          0.025642
# std           0.158065
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: governance_topic_illuminating, dtype: float64
#
# Column: health_topic_illuminating
# count    246745.000000
# mean          0.109190
# std           0.311878
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: health_topic_illuminating, dtype: float64
#
# Column: immigration_topic_illuminating
# count    246745.000000
# mean          0.033569
# std           0.180118
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: immigration_topic_illuminating, dtype: float64
#
# Column: lgbtq_issues_topic_illuminating
# count    246745.000000
# mean          0.003230
# std           0.056742
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: lgbtq_issues_topic_illuminating, dtype: float64
#
# Column: military_topic_illuminating
# count    246745.000000
# mean          0.002176
# std           0.046601
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: military_topic_illuminating, dtype: float64
#
# Column: race_and_ethnicity_topic_illuminating
# count    246745.000000
# mean          0.012434
# std           0.110812
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: race_and_ethnicity_topic_illuminating, dtype: float64
#
# Column: safety_topic_illuminating
# count    246745.000000
# mean          0.033723
# std           0.180516
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: safety_topic_illuminating, dtype: float64
#
# Column: social_and_cultural_topic_illuminating
# count    246745.000000
# mean          0.105838
# std           0.307631
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: social_and_cultural_topic_illuminating, dtype: float64
#
# Column: technology_and_privacy_topic_illuminating
# count    246745.000000
# mean          0.001155
# std           0.033966
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: technology_and_privacy_topic_illuminating, dtype: float64
#
# Column: womens_issue_topic_illuminating
# count    246745.000000
# mean          0.080909
# std           0.272697
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: womens_issue_topic_illuminating, dtype: float64
#
# Column: incivility_illuminating
# count    246745.000000
# mean          0.187526
# std           0.390334
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: incivility_illuminating, dtype: float64
#
# Column: freefair_illuminating
# count    246745.000000
# mean          0.006416
# std           0.079840
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: freefair_illuminating, dtype: float64
#
# Column: fraud_illuminating
# count    246745.000000
# mean          0.002638
# std           0.051297
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: fraud_illuminating, dtype: float64
#
# Unique Value Counts:
# page_id: 4475
# ad_id: 246745
# ad_creation_time: 547
# bylines: 3790
# currency: 18
# delivery_by_region: 141122
# demographic_distribution: 215622
# estimated_audience_size: 9
# estimated_impressions: 39
# estimated_spend: 44
# publisher_platforms: 9
# illuminating_scored_message: 26338
# illuminating_mentions: 278
# scam_illuminating: 2
# election_integrity_Truth_illuminating: 2
# advocacy_msg_type_illuminating: 2
# issue_msg_type_illuminating: 2
# attack_msg_type_illuminating: 2
# image_msg_type_illuminating: 2
# cta_msg_type_illuminating: 2
# engagement_cta_subtype_illuminating: 2
# fundraising_cta_subtype_illuminating: 2
# voting_cta_subtype_illuminating: 2
# covid_topic_illuminating: 2
# economy_topic_illuminating: 2
# education_topic_illuminating: 2
# environment_topic_illuminating: 2
# foreign_policy_topic_illuminating: 2
# governance_topic_illuminating: 2
# health_topic_illuminating: 2
# immigration_topic_illuminating: 2
# lgbtq_issues_topic_illuminating: 2
# military_topic_illuminating: 2
# race_and_ethnicity_topic_illuminating: 2
# safety_topic_illuminating: 2
# social_and_cultural_topic_illuminating: 2
# technology_and_privacy_topic_illuminating: 2
# womens_issue_topic_illuminating: 2
# incivility_illuminating: 2
# freefair_illuminating: 2
# fraud_illuminating: 2
#
# Most Frequent Values:
# page_id: 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d
# ad_id: 0000a88a64484883df6ca1fabd357e4c5950e443123ce3f45d1c5b4c621f9783
# ad_creation_time: 2024-10-27
# bylines: HARRIS FOR PRESIDENT
# currency: USD
# delivery_by_region: {}
# demographic_distribution: {}
# estimated_audience_size: 1000001
# estimated_impressions: 499
# estimated_spend: 49
# publisher_platforms: ['facebook', 'instagram']
# illuminating_scored_message: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# illuminating_mentions: []
# scam_illuminating: 0
# election_integrity_Truth_illuminating: 0
# advocacy_msg_type_illuminating: 1
# issue_msg_type_illuminating: 0
# attack_msg_type_illuminating: 0
# image_msg_type_illuminating: 0
# cta_msg_type_illuminating: 1
# engagement_cta_subtype_illuminating: 0
# fundraising_cta_subtype_illuminating: 0
# voting_cta_subtype_illuminating: 0
# covid_topic_illuminating: 0
# economy_topic_illuminating: 0
# education_topic_illuminating: 0
# environment_topic_illuminating: 0
# foreign_policy_topic_illuminating: 0
# governance_topic_illuminating: 0
# health_topic_illuminating: 0
# immigration_topic_illuminating: 0
# lgbtq_issues_topic_illuminating: 0
# military_topic_illuminating: 0
# race_and_ethnicity_topic_illuminating: 0
# safety_topic_illuminating: 0
# social_and_cultural_topic_illuminating: 0
# technology_and_privacy_topic_illuminating: 0
# womens_issue_topic_illuminating: 0
# incivility_illuminating: 0
# freefair_illuminating: 0
# fraud_illuminating: 0
#
# === Grouped Statistics for 2024_fb_ads_president_scored_anon.csv by ['page_id', 'ad_id'] ===
#
# Group: ('0005687f4ac876c135dda2bd5aa60962eced3356228ef01c21c514d263a11128', '10913e6cae50d9aafe81b85c23f4ad11e24bde5d4f24643c14734a19a2733e5e')
#                                                   page_id  \
# count                                                   1
# unique                                                  1
# top     0005687f4ac876c135dda2bd5aa60962eced3356228ef0...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   1                1
# unique                                                  1                1
# top     10913e6cae50d9aafe81b85c23f4ad11e24bde5d4f2464...       2024-08-23
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                               bylines currency  \
# count                               1        1
# unique                              1        1
# top     David Blount for State Senate      USD
# freq                                1        1
# mean                              NaN      NaN
# std                               NaN      NaN
# min                               NaN      NaN
# 25%                               NaN      NaN
# 50%                               NaN      NaN
# 75%                               NaN      NaN
# max                               NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   1
# unique                                                  1
# top     {'Massachusetts': {'spend': 0, 'impressions': ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   1
# unique                                                  1
# top     {'unknown_65+': {'spend': 0, 'impressions': 7}...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                       1.0                    1.0              1.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                     7500.0                 5499.0             49.0  ...
# std                         NaN                    NaN              NaN  ...
# min                      7500.0                 5499.0             49.0  ...
# 25%                      7500.0                 5499.0             49.0  ...
# 50%                      7500.0                 5499.0             49.0  ...
# 75%                      7500.0                 5499.0             49.0  ...
# max                      7500.0                 5499.0             49.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              1.0                         1.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                NaN                         NaN
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    1.0                        1.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      NaN                        NaN
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      1.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       0.0
# std                                        NaN
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         1.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           NaN
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               1.0                      1.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 NaN                      NaN
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     1.0                 1.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       NaN                 NaN
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Group: ('0005687f4ac876c135dda2bd5aa60962eced3356228ef01c21c514d263a11128', '5ae5f50e059148a06b00ef785636346997d35ee843d2900fe795e60bc39a535f')
#                                                   page_id  \
# count                                                   1
# unique                                                  1
# top     0005687f4ac876c135dda2bd5aa60962eced3356228ef0...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   1                1
# unique                                                  1                1
# top     5ae5f50e059148a06b00ef785636346997d35ee843d290...       2024-10-28
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                               bylines currency  \
# count                               1        1
# unique                              1        1
# top     David Blount for State Senate      USD
# freq                                1        1
# mean                              NaN      NaN
# std                               NaN      NaN
# min                               NaN      NaN
# 25%                               NaN      NaN
# 50%                               NaN      NaN
# 75%                               NaN      NaN
# max                               NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   1
# unique                                                  1
# top     {'Alabama': {'spend': 0, 'impressions': 26}, '...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   1
# unique                                                  1
# top     {'female_18-24': {'spend': 0, 'impressions': 3...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                       1.0                    1.0              1.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                     3000.0                 2499.0             49.0  ...
# std                         NaN                    NaN              NaN  ...
# min                      3000.0                 2499.0             49.0  ...
# 25%                      3000.0                 2499.0             49.0  ...
# 50%                      3000.0                 2499.0             49.0  ...
# 75%                      3000.0                 2499.0             49.0  ...
# max                      3000.0                 2499.0             49.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              1.0                         1.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                NaN                         NaN
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    1.0                        1.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      NaN                        NaN
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      1.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       0.0
# std                                        NaN
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         1.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           NaN
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               1.0                      1.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 NaN                      NaN
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     1.0                 1.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       NaN                 NaN
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Group: ('00157b7e28846e0510e1d265c5ea72fea289d9a3e31a91bb3ed242d8b17f4cd8', '715ec14d254bf4e5b576e257e96f77967ef5c27604238eb4eac34d2f8467a10c')
#                                                   page_id  \
# count                                                   1
# unique                                                  1
# top     00157b7e28846e0510e1d265c5ea72fea289d9a3e31a91...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     ad_id ad_creation_time  \
# count                                                   1                1
# unique                                                  1                1
# top     715ec14d254bf4e5b576e257e96f77967ef5c27604238e...       2024-07-29
# freq                                                    1                1
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                    bylines currency  \
# count                    1        1
# unique                   1        1
# top     Teran for Congress      USD
# freq                     1        1
# mean                   NaN      NaN
# std                    NaN      NaN
# min                    NaN      NaN
# 25%                    NaN      NaN
# 50%                    NaN      NaN
# 75%                    NaN      NaN
# max                    NaN      NaN
#
#                                        delivery_by_region  \
# count                                                   1
# unique                                                  1
# top     {'Arizona': {'spend': 1248, 'impressions': 274...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  demographic_distribution  \
# count                                                   1
# unique                                                  1
# top     {'unknown_18-24': {'spend': 0, 'impressions': ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         estimated_audience_size  estimated_impressions  estimated_spend  ...  \
# count                       1.0                    1.0              1.0  ...
# unique                      NaN                    NaN              NaN  ...
# top                         NaN                    NaN              NaN  ...
# freq                        NaN                    NaN              NaN  ...
# mean                    30000.0                27499.0           1249.0  ...
# std                         NaN                    NaN              NaN  ...
# min                     30000.0                27499.0           1249.0  ...
# 25%                     30000.0                27499.0           1249.0  ...
# 50%                     30000.0                27499.0           1249.0  ...
# 75%                     30000.0                27499.0           1249.0  ...
# max                     30000.0                27499.0           1249.0  ...
#
#        lgbtq_issues_topic_illuminating military_topic_illuminating  \
# count                              1.0                         1.0
# unique                             NaN                         NaN
# top                                NaN                         NaN
# freq                               NaN                         NaN
# mean                               0.0                         0.0
# std                                NaN                         NaN
# min                                0.0                         0.0
# 25%                                0.0                         0.0
# 50%                                0.0                         0.0
# 75%                                0.0                         0.0
# max                                0.0                         0.0
#
#        race_and_ethnicity_topic_illuminating  safety_topic_illuminating  \
# count                                    1.0                        1.0
# unique                                   NaN                        NaN
# top                                      NaN                        NaN
# freq                                     NaN                        NaN
# mean                                     0.0                        0.0
# std                                      NaN                        NaN
# min                                      0.0                        0.0
# 25%                                      0.0                        0.0
# 50%                                      0.0                        0.0
# 75%                                      0.0                        0.0
# max                                      0.0                        0.0
#
#         social_and_cultural_topic_illuminating  \
# count                                      1.0
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                       1.0
# std                                        NaN
# min                                        1.0
# 25%                                        1.0
# 50%                                        1.0
# 75%                                        1.0
# max                                        1.0
#
#         technology_and_privacy_topic_illuminating  \
# count                                         1.0
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# mean                                          0.0
# std                                           NaN
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
#         womens_issue_topic_illuminating  incivility_illuminating  \
# count                               1.0                      1.0
# unique                              NaN                      NaN
# top                                 NaN                      NaN
# freq                                NaN                      NaN
# mean                                0.0                      0.0
# std                                 NaN                      NaN
# min                                 0.0                      0.0
# 25%                                 0.0                      0.0
# 50%                                 0.0                      0.0
# 75%                                 0.0                      0.0
# max                                 0.0                      0.0
#
#         freefair_illuminating  fraud_illuminating
# count                     1.0                 1.0
# unique                    NaN                 NaN
# top                       NaN                 NaN
# freq                      NaN                 NaN
# mean                      0.0                 0.0
# std                       NaN                 NaN
# min                       0.0                 0.0
# 25%                       0.0                 0.0
# 50%                       0.0                 0.0
# 75%                       0.0                 0.0
# max                       0.0                 0.0
#
# [11 rows x 41 columns]
#
# Loaded 19009 rows and 56 columns from 2024_fb_posts_president_scored_anon.csv
#
# === Overall Descriptive Statistics for 2024_fb_posts_president_scored_anon.csv ===
#
# Column: Facebook_Id
# count                                                 19009
# unique                                                   21
# top       32fc18da91029ff09bf74fe9887eace6b5d2145809d583...
# freq                                                   9013
# Name: Facebook_Id, dtype: object
#
# Column: post_id
# count                                                 19009
# unique                                                19009
# top       8570b69695e00d8f06b12398ed525497e1712b5369c6fc...
# freq                                                      1
# Name: post_id, dtype: object
#
# Column: Page Category
# count      16537
# unique         6
# top       PERSON
# freq        9453
# Name: Page Category, dtype: object
#
# Column: Page Admin Top Country
# count     16280
# unique        1
# top          US
# freq      16280
# Name: Page Admin Top Country, dtype: object
#
# Column: Post Created
# count                        19009
# unique                       18951
# top       2024-09-30T13:47:21.000Z
# freq                             2
# Name: Post Created, dtype: object
#
# Column: Post Created Date
# count          19009
# unique           425
# top       2024-10-31
# freq             103
# Name: Post Created Date, dtype: object
#
# Column: Post Created Time
# count        19009
# unique       16102
# top       17:30:01
# freq             7
# Name: Post Created Time, dtype: object
#
# Column: Type
# count     16544
# unique        9
# top        Link
# freq       7404
# Name: Type, dtype: object
#
# Column: Total Interactions
# count     19009
# unique     5665
# top          15
# freq        115
# Name: Total Interactions, dtype: object
#
# Column: Likes
# count     19009.000000
# mean       2377.695407
# std       11253.469669
# min           0.000000
# 25%          31.000000
# 50%         139.000000
# 75%         738.000000
# max      351979.000000
# Name: Likes, dtype: float64
#
# Column: Comments
# count    19009.000000
# mean       901.583197
# std       3681.980096
# min          0.000000
# 25%          8.000000
# 50%         48.000000
# 75%        354.000000
# max      93872.000000
# Name: Comments, dtype: float64
#
# Column: Shares
# count    19009.000000
# mean       320.538955
# std       1722.159879
# min          0.000000
# 25%          3.000000
# 50%         21.000000
# 75%        102.000000
# max      76150.000000
# Name: Shares, dtype: float64
#
# Column: Love
# count     19009.000000
# mean        413.877321
# std        3730.940450
# min           0.000000
# 25%           0.000000
# 50%           4.000000
# 75%          70.000000
# max      244482.000000
# Name: Love, dtype: float64
#
# Column: Wow
# count    19009.000000
# mean         5.868326
# std         52.946979
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max       4345.000000
# Name: Wow, dtype: float64
#
# Column: Haha
# count    19009.000000
# mean       105.719712
# std        942.034248
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%         29.000000
# max      99276.000000
# Name: Haha, dtype: float64
#
# Column: Sad
# count    19009.000000
# mean        10.172182
# std        418.325007
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max      56111.000000
# Name: Sad, dtype: float64
#
# Column: Angry
# count    19009.000000
# mean        20.055500
# std        156.020089
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          9.000000
# max      11814.000000
# Name: Angry, dtype: float64
#
# Column: Care
# count    19009.000000
# mean        34.929034
# std        790.103213
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          6.000000
# max      85236.000000
# Name: Care, dtype: float64
#
# Column: Video Share Status
# count      3271
# unique        3
# top       owned
# freq       3100
# Name: Video Share Status, dtype: object
#
# Column: Is Video Owner?
# count     16544
# unique        3
# top           -
# freq      13280
# Name: Is Video Owner?, dtype: object
#
# Column: Post Views
# count    1.654400e+04
# mean     6.485059e+03
# std      9.039296e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.276477e+06
# Name: Post Views, dtype: float64
#
# Column: Total Views
# count    1.654400e+04
# mean     7.461847e+03
# std      9.597628e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.462155e+06
# Name: Total Views, dtype: float64
#
# Column: Total Views For All Crossposts
# count    1.654400e+04
# mean     3.555938e+03
# std      8.809405e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.499458e+06
# Name: Total Views For All Crossposts, dtype: float64
#
# Column: Video Length
# count         3271
# unique         774
# top       00:00:30
# freq            83
# Name: Video Length, dtype: object
#
# Column: Sponsor Id
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Sponsor Id, dtype: float64
#
# Column: Sponsor Name
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Sponsor Name, dtype: float64
#
# Column: Sponsor Category
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Sponsor Category, dtype: float64
#
# Column: Overperforming Score
# count    16544.000000
# mean        -2.744160
# std          7.808477
# min       -198.750000
# 25%         -3.870000
# 50%         -1.620000
# 75%          1.160000
# max        246.780000
# Name: Overperforming Score, dtype: float64
#
# Column: illuminating_scored_messageelection_integrity_Truth_illuminating
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: illuminating_scored_messageelection_integrity_Truth_illuminating, dtype: float64
#
# Column: advocacy_msg_type_illuminating
# count    19009.000000
# mean         0.549266
# std          0.497580
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: advocacy_msg_type_illuminating, dtype: float64
#
# Column: issue_msg_type_illuminating
# count    19009.000000
# mean         0.460308
# std          0.498435
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: issue_msg_type_illuminating, dtype: float64
#
# Column: attack_msg_type_illuminating
# count    19009.000000
# mean         0.216687
# std          0.411998
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: attack_msg_type_illuminating, dtype: float64
#
# Column: image_msg_type_illuminating
# count    19009.000000
# mean         0.148561
# std          0.355665
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# ...
# freefair_illuminating: 2
# fraud_illuminating: 2
#
# Most Frequent Values:
# Facebook_Id: 32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064
# post_id: 0001e4a1dbadf84f0f43719972b60597cc79f1908bf60125779280f2a0054781
# Page Category: PERSON
# Page Admin Top Country: US
# Post Created: 2023-11-14 11:11:44 EST
# Post Created Date: 2024-10-31
# Post Created Time: 17:30:01
# Type: Link
# Total Interactions: 15
# Likes: 9
# Comments: 0
# Shares: 0
# Love: 0
# Wow: 0
# Haha: 0
# Sad: 0
# Angry: 0
# Care: 0
# Video Share Status: owned
# Is Video Owner?: -
# Post Views: 0.0
# Total Views: 0.0
# Total Views For All Crossposts: 0.0
# Video Length: 00:00:30
# Overperforming Score: -1.03
# advocacy_msg_type_illuminating: 1
# issue_msg_type_illuminating: 0
# attack_msg_type_illuminating: 0
# image_msg_type_illuminating: 0
# cta_msg_type_illuminating: 0
# engagement_cta_subtype_illuminating: 0
# fundraising_cta_subtype_illuminating: 0
# voting_cta_subtype_illuminating: 0
# covid_topic_illuminating: 0
# economy_topic_illuminating: 0
# education_topic_illuminating: 0
# environment_topic_illuminating: 0
# foreign_policy_topic_illuminating: 0
# governance_topic_illuminating: 0
# health_topic_illuminating: 0
# immigration_topic_illuminating: 0
# lgbtq_issues_topic_illuminating: 0
# military_topic_illuminating: 0
# race_and_ethnicity_topic_illuminating: 0
# safety_topic_illuminating: 0
# social_and_cultural_topic_illuminating: 0
# technology_and_privacy_topic_illuminating: 0
# womens_issue_topic_illuminating: 0
# incivility_illuminating: 0
# scam_illuminating: 0.0
# freefair_illuminating: 0
# fraud_illuminating: 0
#
# No grouping columns ('page_id', 'ad_id', or 'state') found in 2024_fb_posts_president_scored_anon.csv. Skipping grouping.
#
# Loaded 27304 rows and 47 columns from 2024_tw_posts_president_scored_anon.csv
#
# === Overall Descriptive Statistics for 2024_tw_posts_president_scored_anon.csv ===
#
# Column: id
# count                                                 27304
# unique                                                27304
# top       cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a...
# freq                                                      1
# Name: id, dtype: object
#
# Column: url
# count                                                 27304
# unique                                                27304
# top       f70a206472e9deaf6e313297c1efb891729ced346a0aeb...
# freq                                                      1
# Name: url, dtype: object
#
# Column: source
# count               27304
# unique                 14
# top       Twitter Web App
# freq                14930
# Name: source, dtype: object
#
# Column: retweetCount
# count     27304.000000
# mean       1322.055193
# std        3405.004240
# min           0.000000
# 25%          84.000000
# 50%         333.000000
# 75%        1071.000000
# max      144615.000000
# Name: retweetCount, dtype: float64
#
# Column: replyCount
# count     27304.000000
# mean       1063.785013
# std        3174.981654
# min           0.000000
# 25%          43.000000
# 50%         131.000000
# 75%         501.250000
# max      121270.000000
# Name: replyCount, dtype: float64
#
# Column: likeCount
# count     27304.000000
# mean       6913.692829
# std       21590.307989
# min           0.000000
# 25%         393.000000
# 50%        1406.000000
# 75%        5010.000000
# max      915221.000000
# Name: likeCount, dtype: float64
#
# Column: quoteCount
# count     27304.000000
# mean        128.081563
# std        1131.533468
# min           0.000000
# 25%           5.000000
# 50%          17.000000
# 75%          69.000000
# max      123320.000000
# Name: quoteCount, dtype: float64
#
# Column: viewCount
# count    2.730400e+04
# mean     5.070847e+05
# std      3.212174e+06
# min      5.000000e+00
# 25%      2.785275e+04
# 50%      7.094200e+04
# 75%      3.036630e+05
# max      3.335028e+08
# Name: viewCount, dtype: float64
#
# Column: createdAt
# count                   27304
# unique                  27014
# top       2023-10-06 04:55:21
# freq                        4
# Name: createdAt, dtype: object
#
# Column: lang
# count     27304
# unique       12
# top          en
# freq      27281
# Name: lang, dtype: object
#
# Column: bookmarkCount
# count    27304.000000
# mean       136.213522
# std        712.580294
# min          0.000000
# 25%          4.000000
# 50%         21.000000
# 75%         76.000000
# max      42693.000000
# Name: bookmarkCount, dtype: float64
#
# Column: isReply
# count     27304
# unique        2
# top       False
# freq      23930
# Name: isReply, dtype: object
#
# Column: isRetweet
# count     27304
# unique        1
# top       False
# freq      27304
# Name: isRetweet, dtype: object
#
# Column: isQuote
# count     27304
# unique        2
# top       False
# freq      24064
# Name: isQuote, dtype: object
#
# Column: isConversationControlled
# count     27304
# unique        2
# top       False
# freq      27296
# Name: isConversationControlled, dtype: object
#
# Column: quoteId
# count    3.287000e+03
# mean     1.764298e+18
# std      6.894687e+16
# min      7.912639e+17
# 25%      1.726459e+18
# 50%      1.756496e+18
# 75%      1.816599e+18
# max      1.853576e+18
# Name: quoteId, dtype: float64
#
# Column: inReplyToId
# count    3.345000e+03
# mean     1.758286e+18
# std      4.361197e+16
# min      1.240067e+18
# 25%      1.726801e+18
# 50%      1.746641e+18
# 75%      1.789226e+18
# max      1.853531e+18
# Name: inReplyToId, dtype: float64
#
# Column: month_year
# count       27304
# unique         15
# top       2024-10
# freq         3586
# Name: month_year, dtype: object
#
# Column: illuminating_scored_message
# count                                                 27304
# unique                                                27136
# top       36cb7d55fcf85362ca03f624c2f574f1f55f89db559b17...
# freq                                                     21
# Name: illuminating_scored_message, dtype: object
#
# Column: election_integrity_Truth_illuminating
# count    26034.000000
# mean         0.037144
# std          0.189118
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: election_integrity_Truth_illuminating, dtype: float64
#
# Column: advocacy_msg_type_illuminating
# count    26034.000000
# mean         0.563686
# std          0.495937
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: advocacy_msg_type_illuminating, dtype: float64
#
# Column: issue_msg_type_illuminating
# count    26034.000000
# mean         0.507682
# std          0.499951
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: issue_msg_type_illuminating, dtype: float64
#
# Column: attack_msg_type_illuminating
# count    26034.000000
# mean         0.307598
# std          0.461508
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: attack_msg_type_illuminating, dtype: float64
#
# Column: image_msg_type_illuminating
# count    26034.000000
# mean         0.226435
# std          0.418532
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: image_msg_type_illuminating, dtype: float64
#
# Column: cta_msg_type_illuminating
# count    26034.000000
# mean         0.109664
# std          0.312477
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: cta_msg_type_illuminating, dtype: float64
#
# Column: engagement_cta_subtype_illuminating
# count    26034.000000
# mean         0.066912
# std          0.249875
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: engagement_cta_subtype_illuminating, dtype: float64
#
# Column: fundraising_cta_subtype_illuminating
# count    26034.000000
# mean         0.007874
# std          0.088389
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: fundraising_cta_subtype_illuminating, dtype: float64
#
# Column: voting_cta_subtype_illuminating
# count    26034.000000
# mean         0.016786
# std          0.128470
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: voting_cta_subtype_illuminating, dtype: float64
#
# Column: covid_topic_illuminating
# count    26034.000000
# mean         0.007605
# std          0.086879
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: covid_topic_illuminating, dtype: float64
#
# Column: economy_topic_illuminating
# count    26034.000000
# mean         0.160214
# std          0.366811
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: economy_topic_illuminating, dtype: float64
#
# Column: education_topic_illuminating
# count    26034.000000
# mean         0.018437
# std          0.134529
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: education_topic_illuminating, dtype: float64
#
# Column: environment_topic_illuminating
# count    26034.000000
# mean         0.028540
# std          0.166512
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: environment_topic_illuminating, dtype: float64
#
# Column: foreign_policy_topic_illuminating
# count    26034.000000
# mean         0.042252
# std          0.201168
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: foreign_policy_topic_illuminating, dtype: float64
#
# Column: governance_topic_illuminating
# count    26034.000000
# mean         0.022970
# std          0.149811
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: governance_topic_illuminating, dtype: float64
#
# Column: health_topic_illuminating
# count    26034.000000
# mean         0.055658
# std          0.229264
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: health_topic_illuminating, dtype: float64
#
# Column: immigration_topic_illuminating
# count    26034.000000
# mean         0.065299
# std          0.247058
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: immigration_topic_illuminating, dtype: float64
#
# Column: lgbtq_issues_topic_illuminating
# count    26034.000000
# mean         0.003073
# std          0.055350
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: lgbtq_issues_topic_illuminating, dtype: float64
#
# Column: military_topic_illuminating
# count    26034.000000
# mean         0.010986
# std          0.104237
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: military_topic_illuminating, dtype: float64
#
# Column: race_and_ethnicity_topic_illuminating
# count    26034.000000
# mean         0.015403
# std          0.123151
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: race_and_ethnicity_topic_illuminating, dtype: float64
#
# Column: safety_topic_illuminating
# count    26034.000000
# mean         0.037605
# std          0.190242
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: safety_topic_illuminating, dtype: float64
#
# Column: social_and_cultural_topic_illuminating
# count    26034.000000
# mean         0.051971
# std          0.221972
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: social_and_cultural_topic_illuminating, dtype: float64
#
# Column: technology_and_privacy_topic_illuminating
# count    26034.000000
# mean         0.002036
# std          0.045075
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: technology_and_privacy_topic_illuminating, dtype: float64
#
# Column: womens_issue_topic_illuminating
# count    26034.000000
# mean         0.023316
# std          0.150907
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: womens_issue_topic_illuminating, dtype: float64
#
# Column: incivility_illuminating
# count    26034.000000
# mean         0.178574
# std          0.383003
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: incivility_illuminating, dtype: float64
#
# Column: scam_illuminating
# count    26034.000000
# mean         0.012368
# std          0.110526
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: scam_illuminating, dtype: float64
#
# Column: freefair_illuminating
# count    27304.000000
# mean         0.001428
# std          0.037767
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: freefair_illuminating, dtype: float64
#
# Column: fraud_illuminating
# count    27304.000000
# mean         0.002747
# std          0.052339
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: fraud_illuminating, dtype: float64
#
# Unique Value Counts:
# id: 27304
# url: 27304
# source: 14
# retweetCount: 5197
# replyCount: 4517
# likeCount: 10202
# quoteCount: 1346
# viewCount: 25369
# createdAt: 27014
# lang: 12
# bookmarkCount: 1440
# isReply: 2
# isRetweet: 1
# isQuote: 2
# isConversationControlled: 2
# quoteId: 3159
# inReplyToId: 3309
# month_year: 15
# illuminating_scored_message: 27136
# election_integrity_Truth_illuminating: 2
# advocacy_msg_type_illuminating: 2
# issue_msg_type_illuminating: 2
# attack_msg_type_illuminating: 2
# image_msg_type_illuminating: 2
# cta_msg_type_illuminating: 2
# engagement_cta_subtype_illuminating: 2
# fundraising_cta_subtype_illuminating: 2
# voting_cta_subtype_illuminating: 2
# covid_topic_illuminating: 2
# economy_topic_illuminating: 2
# education_topic_illuminating: 2
# environment_topic_illuminating: 2
# foreign_policy_topic_illuminating: 2
# governance_topic_illuminating: 2
# health_topic_illuminating: 2
# immigration_topic_illuminating: 2
# lgbtq_issues_topic_illuminating: 2
# military_topic_illuminating: 2
# race_and_ethnicity_topic_illuminating: 2
# safety_topic_illuminating: 2
# social_and_cultural_topic_illuminating: 2
# technology_and_privacy_topic_illuminating: 2
# womens_issue_topic_illuminating: 2
# incivility_illuminating: 2
# scam_illuminating: 2
# freefair_illuminating: 2
# fraud_illuminating: 2
#
# Most Frequent Values:
# id: 0000635d0c9e7bdf89dfc13811d080dbffac54894594354aa0876b3c12d59aeb
# url: 0000179c6b90798f167528aaaaf67886a975ea68af78f4f342822fae858fdcf1
# source: Twitter Web App
# retweetCount: 0
# replyCount: 1
# likeCount: 1
# quoteCount: 0
# viewCount: 96
# createdAt: 2023-10-06 04:55:21
# lang: en
# bookmarkCount: 0
# isReply: False
# isRetweet: False
# isQuote: False
# isConversationControlled: False
# quoteId: 1.711730672279122e+18
# inReplyToId: 1.7444996006715807e+18
# month_year: 2024-10
# illuminating_scored_message: 36cb7d55fcf85362ca03f624c2f574f1f55f89db559b17da084df6e643afe5cd
# election_integrity_Truth_illuminating: 0.0
# advocacy_msg_type_illuminating: 1.0
# issue_msg_type_illuminating: 1.0
# attack_msg_type_illuminating: 0.0
# image_msg_type_illuminating: 0.0
# cta_msg_type_illuminating: 0.0
# engagement_cta_subtype_illuminating: 0.0
# fundraising_cta_subtype_illuminating: 0.0
# voting_cta_subtype_illuminating: 0.0
# covid_topic_illuminating: 0.0
# economy_topic_illuminating: 0.0
# education_topic_illuminating: 0.0
# environment_topic_illuminating: 0.0
# foreign_policy_topic_illuminating: 0.0
# governance_topic_illuminating: 0.0
# health_topic_illuminating: 0.0
# immigration_topic_illuminating: 0.0
# lgbtq_issues_topic_illuminating: 0.0
# military_topic_illuminating: 0.0
# race_and_ethnicity_topic_illuminating: 0.0
# safety_topic_illuminating: 0.0
# social_and_cultural_topic_illuminating: 0.0
# technology_and_privacy_topic_illuminating: 0.0
# womens_issue_topic_illuminating: 0.0
# incivility_illuminating: 0.0
# scam_illuminating: 0.0
# freefair_illuminating: 0
# fraud_illuminating: 0
#
# No grouping columns ('page_id', 'ad_id', or 'state') found in 2024_tw_posts_president_scored_anon.csv. Skipping grouping.
