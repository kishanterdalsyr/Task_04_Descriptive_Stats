# %%
import csv
import math
import os
from collections import Counter, defaultdict

DATA_PATHS = [
    '/Users/kishanterdal/Downloads/period_03/2024_fb_ads_president_scored_anon.csv',
    '/Users/kishanterdal/Downloads/period_03/2024_fb_posts_president_scored_anon.csv',
    '/Users/kishanterdal/Downloads/period_03/2024_tw_posts_president_scored_anon.csv'
]

def load_data(filepath):
    with open(filepath, mode='r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        data = list(reader)
    return data

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

def overall_statistics(data, dataset_name):
    print(f"\n=== Overall Statistics for {dataset_name} ===")
    if not data:
        print("No data available.")
        return

    columns = data[0].keys()
    for col in columns:
        col_values = [row[col] for row in data if row[col] != '']
        numeric_values = [float(v) for v in col_values if is_numeric(v)]

        print(f"\nColumn: {col}")
        print(f"Count: {len(col_values)}")

        if numeric_values:
            mean = sum(numeric_values) / len(numeric_values)
            min_val = min(numeric_values)
            max_val = max(numeric_values)
            stdev = math.sqrt(sum((x - mean) ** 2 for x in numeric_values) / len(numeric_values))

            print(f"Mean: {mean}")
            print(f"Min: {min_val}")
            print(f"Max: {max_val}")
            print(f"Standard Deviation: {stdev}")
        else:
            value_counts = Counter(col_values)
            most_common = value_counts.most_common(1)[0] if value_counts else ('N/A', 0)

            print(f"Unique Values: {len(set(col_values))}")
            print(f"Most Frequent Value: {most_common[0]} (Count: {most_common[1]})")

def group_statistics(data, group_cols, dataset_name):
    print(f"\n=== Grouped Statistics for {dataset_name} by {group_cols} ===")
    grouped_data = defaultdict(list)

    for row in data:
        key = tuple(row[col] for col in group_cols)
        grouped_data[key].append(row)

    for i, (group_key, group_rows) in enumerate(grouped_data.items()):
        if i >= 3:
            break
        print(f"\nGroup: {group_key}")
        overall_statistics(group_rows, f"{dataset_name} - Group {group_key}")

def analyze_dataset(filepath):
    if not os.path.isfile(filepath):
        print(f"File {filepath} does not exist. Skipping...")
        return

    data = load_data(filepath)
    dataset_name = os.path.basename(filepath)
    print(f"\nLoaded {len(data)} rows from {dataset_name}")

    overall_statistics(data, dataset_name)

    if data:
        columns = data[0].keys()
        if 'page_id' in columns and 'ad_id' in columns:
            group_statistics(data, ['page_id', 'ad_id'], dataset_name)
        elif 'page_id' in columns:
            group_statistics(data, ['page_id'], dataset_name)
        elif 'state' in columns:
            group_statistics(data, ['state'], dataset_name)
        else:
            print(f"No grouping columns ('page_id', 'ad_id', 'state') found in {dataset_name}.")

def main():
    for filepath in DATA_PATHS:
        analyze_dataset(filepath)

if __name__ == "__main__":
    main()
# Out:
# Loaded 246745 rows from 2024_fb_ads_president_scored_anon.csv
#
# === Overall Statistics for 2024_fb_ads_president_scored_anon.csv ===
#
# Column: page_id
# Count: 246745
# Unique Values: 4475
# Most Frequent Value: 4d66f5853f0365dba032a87704a634f023d15babde973bb7a284ed8cd2707b2d (Count: 55503)
#
# Column: ad_id
# Count: 246745
# Unique Values: 246745
# Most Frequent Value: 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc (Count: 1)
#
# Column: ad_creation_time
# Count: 246745
# Unique Values: 547
# Most Frequent Value: 2024-10-27 (Count: 8619)
#
# Column: bylines
# Count: 245736
# Unique Values: 3790
# Most Frequent Value: HARRIS FOR PRESIDENT (Count: 49788)
#
# Column: currency
# Count: 246745
# Unique Values: 18
# Most Frequent Value: USD (Count: 246599)
#
# Column: delivery_by_region
# Count: 246745
# Unique Values: 141122
# Most Frequent Value: {} (Count: 30989)
#
# Column: demographic_distribution
# Count: 246745
# Unique Values: 215622
# Most Frequent Value: {} (Count: 30989)
#
# Column: estimated_audience_size
# Count: 246745
# Mean: 556462.8559687126
# Min: 0.0
# Max: 1000001.0
# Standard Deviation: 409863.92827886896
#
# Column: estimated_impressions
# Count: 246745
# Mean: 45601.52595189366
# Min: 499.0
# Max: 1000000.0
# Standard Deviation: 136790.49271013253
#
# Column: estimated_spend
# Count: 246745
# Mean: 1061.2914344768892
# Min: 49.0
# Max: 474999.0
# Standard Deviation: 4992.550631937455
#
# Column: publisher_platforms
# Count: 246745
# Unique Values: 9
# Most Frequent Value: ['facebook', 'instagram'] (Count: 214434)
#
# Column: illuminating_scored_message
# Count: 246745
# Unique Values: 26338
# Most Frequent Value: e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855 (Count: 5972)
#
# Column: illuminating_mentions
# Count: 246745
# Unique Values: 278
# Most Frequent Value: [] (Count: 73205)
#
# Column: scam_illuminating
# Count: 246745
# Mean: 0.07163265719670105
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.25787869167401956
#
# Column: election_integrity_Truth_illuminating
# Count: 246745
# Mean: 0.05008814768283045
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.21812685562386466
#
# Column: advocacy_msg_type_illuminating
# Count: 246745
# Mean: 0.5486311779367363
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.49762938873554086
#
# Column: issue_msg_type_illuminating
# Count: 246745
# Mean: 0.38164907090315914
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.48579116663745425
#
# Column: attack_msg_type_illuminating
# Count: 246745
# Mean: 0.27185555938316885
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.44491585071297657
#
# Column: image_msg_type_illuminating
# Count: 246745
# Mean: 0.22270360088350322
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.41606094149425504
#
# Column: cta_msg_type_illuminating
# Count: 246745
# Mean: 0.5727694583476869
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.49467626376455676
#
# Column: engagement_cta_subtype_illuminating
# Count: 246745
# Mean: 0.12486980485926767
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.33057122786673815
#
# Column: fundraising_cta_subtype_illuminating
# Count: 246745
# Mean: 0.22848689943058623
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.4198578762138146
#
# Column: voting_cta_subtype_illuminating
# Count: 246745
# Mean: 0.1438448600782184
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.3509323528945909
#
# Column: covid_topic_illuminating
# Count: 246745
# Mean: 0.024875884009807697
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.15574682791132594
#
# Column: economy_topic_illuminating
# Count: 246745
# Mean: 0.12212202881517356
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.32742669239523003
#
# Column: education_topic_illuminating
# Count: 246745
# Mean: 0.01432653143934021
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.1188330001984883
#
# Column: environment_topic_illuminating
# Count: 246745
# Mean: 0.02124865752092241
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.14421217727521354
#
# Column: foreign_policy_topic_illuminating
# Count: 246745
# Mean: 0.005264544367667025
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.07236593770745813
#
# Column: governance_topic_illuminating
# Count: 246745
# Mean: 0.025641856977851627
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.15806439241179096
#
# Column: health_topic_illuminating
# Count: 246745
# Mean: 0.10918964923301384
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.3118770105887304
#
# Column: immigration_topic_illuminating
# Count: 246745
# Mean: 0.03356906928205232
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.18011714762810338
#
# Column: lgbtq_issues_topic_illuminating
# Count: 246745
# Mean: 0.0032300553202699142
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.05674171360548478
#
# Column: military_topic_illuminating
# Count: 246745
# Mean: 0.002176335893331172
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.046600423339389845
#
# Column: race_and_ethnicity_topic_illuminating
# Count: 246745
# Mean: 0.01243388923787716
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.11081194717288713
#
# Column: safety_topic_illuminating
# Count: 246745
# Mean: 0.03372307442906645
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.18051545274632563
#
# Column: social_and_cultural_topic_illuminating
# Count: 246745
# Mean: 0.10583801090194331
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.30763017789314195
#
# Column: technology_and_privacy_topic_illuminating
# Count: 246745
# Mean: 0.0011550386026059293
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.03396622570185294
#
# Column: womens_issue_topic_illuminating
# Count: 246745
# Mean: 0.08090944092078867
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.2726959906028699
#
# Column: incivility_illuminating
# Count: 246745
# Mean: 0.18752558309185596
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.3903328563900049
#
# Column: freefair_illuminating
# Count: 246745
# Mean: 0.006415530203246266
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.07983965916440881
#
# Column: fraud_illuminating
# Count: 246745
# Mean: 0.0026383513343735433
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.05129708019557693
#
# === Grouped Statistics for 2024_fb_ads_president_scored_anon.csv by ['page_id', 'ad_id'] ===
#
# Group: ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc')
#
# === Overall Statistics for 2024_fb_ads_president_scored_anon.csv - Group ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc') ===
#
# Column: page_id
# Count: 1
# Unique Values: 1
# Most Frequent Value: 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230 (Count: 1)
#
# Column: ad_id
# Count: 1
# Unique Values: 1
# Most Frequent Value: 0ddb025b8544e2d58e6977ad417e742a52522b3e1fc1c9d9b61c57148f8d72fc (Count: 1)
#
# Column: ad_creation_time
# Count: 1
# Unique Values: 1
# Most Frequent Value: 2024-10-21 (Count: 1)
#
# Column: bylines
# Count: 1
# Unique Values: 1
# Most Frequent Value: Texas Organizing Project PAC (Count: 1)
#
# Column: currency
# Count: 1
# Unique Values: 1
# Most Frequent Value: USD (Count: 1)
#
# Column: delivery_by_region
# Count: 1
# Unique Values: 1
# Most Frequent Value: {'Texas': {'spend': 249, 'impressions': 47499}} (Count: 1)
#
# Column: demographic_distribution
# Count: 1
# Unique Values: 1
# Most Frequent Value: {'female_18-24': {'spend': 28, 'impressions': 5507}, 'male_45-54': {'spend': 14, 'impressions': 2757}, 'male_65+': {'spend': 3, 'impressions': 714}, 'female_65+': {'spend': 3, 'impressions': 725}, 'unknown_55-64': {'spend': 0, 'impressions': 21}, 'male_55-64': {'spend': 7, 'impressions': 1502}, 'female_55-64': {'spend': 7, 'impressions': 1520}, 'unknown_45-54': {'spend': 0, 'impressions': 40}, 'female_45-54': {'spend': 14, 'impressions': 2735}, 'male_18-24': {'spend': 21, 'impressions': 4055}, 'unknown_35-44': {'spend': 0, 'impressions': 69}, 'male_35-44': {'spend': 26, 'impressions': 5149}, 'female_35-44': {'spend': 28, 'impressions': 5528}, 'unknown_25-34': {'spend': 0, 'impressions': 91}, 'male_25-34': {'spend': 41, 'impressions': 7976}, 'female_25-34': {'spend': 46, 'impressions': 8920}, 'unknown_18-24': {'spend': 0, 'impressions': 171}, 'unknown_65+': {'spend': 0, 'impressions': 10}} (Count: 1)
#
# Column: estimated_audience_size
# Count: 1
# Mean: 30000.0
# Min: 30000.0
# Max: 30000.0
# Standard Deviation: 0.0
#
# Column: estimated_impressions
# Count: 1
# Mean: 47499.0
# Min: 47499.0
# Max: 47499.0
# Standard Deviation: 0.0
#
# Column: estimated_spend
# Count: 1
# Mean: 249.0
# Min: 249.0
# Max: 249.0
# Standard Deviation: 0.0
#
# Column: publisher_platforms
# Count: 1
# Unique Values: 1
# Most Frequent Value: ['facebook', 'instagram'] (Count: 1)
#
# Column: illuminating_scored_message
# Count: 1
# Unique Values: 1
# Most Frequent Value: 362d68d42e34e070bc9f999033642b8fddfca5404195fc27690c60e0acde1d5b (Count: 1)
#
# Column: illuminating_mentions
# Count: 1
# Unique Values: 1
# Most Frequent Value: ['Kamala Harris', 'Tim Walz'] (Count: 1)
#
# Column: scam_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: election_integrity_Truth_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: advocacy_msg_type_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: issue_msg_type_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: attack_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: image_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: cta_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: engagement_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: fundraising_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: voting_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: covid_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: economy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: education_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: environment_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: foreign_policy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: governance_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: health_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: immigration_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: lgbtq_issues_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: military_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: race_and_ethnicity_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: safety_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: social_and_cultural_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: technology_and_privacy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: womens_issue_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: incivility_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: freefair_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: fraud_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Group: ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6')
#
# === Overall Statistics for 2024_fb_ads_president_scored_anon.csv - Group ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6') ===
#
# Column: page_id
# Count: 1
# Unique Values: 1
# Most Frequent Value: 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230 (Count: 1)
#
# Column: ad_id
# Count: 1
# Unique Values: 1
# Most Frequent Value: 86229868e6bde3661724fe02da93504bb4fb5da8c2550d7b7cf193c687e89fa6 (Count: 1)
#
# Column: ad_creation_time
# Count: 1
# Unique Values: 1
# Most Frequent Value: 2024-10-18 (Count: 1)
#
# Column: bylines
# Count: 1
# Unique Values: 1
# Most Frequent Value: Texas Organizing Project PAC (Count: 1)
#
# Column: currency
# Count: 1
# Unique Values: 1
# Most Frequent Value: USD (Count: 1)
#
# Column: delivery_by_region
# Count: 1
# Unique Values: 1
# Most Frequent Value: {'Texas': {'spend': 49, 'impressions': 22499}} (Count: 1)
#
# Column: demographic_distribution
# Count: 1
# Unique Values: 1
# Most Frequent Value: {'female_18-24': {'spend': 8, 'impressions': 3904}, 'male_45-54': {'spend': 2, 'impressions': 1129}, 'male_65+': {'spend': 0, 'impressions': 299}, 'female_65+': {'spend': 0, 'impressions': 251}, 'unknown_55-64': {'spend': 0, 'impressions': 5}, 'male_55-64': {'spend': 1, 'impressions': 602}, 'female_55-64': {'spend': 0, 'impressions': 456}, 'unknown_45-54': {'spend': 0, 'impressions': 15}, 'female_45-54': {'spend': 1, 'impressions': 856}, 'male_18-24': {'spend': 6, 'impressions': 2922}, 'unknown_35-44': {'spend': 0, 'impressions': 23}, 'male_35-44': {'spend': 4, 'impressions': 2145}, 'female_35-44': {'spend': 3, 'impressions': 1726}, 'unknown_25-34': {'spend': 0, 'impressions': 31}, 'male_25-34': {'spend': 9, 'impressions': 4323}, 'female_25-34': {'spend': 8, 'impressions': 3744}, 'unknown_18-24': {'spend': 0, 'impressions': 53}, 'unknown_65+': {'spend': 0, 'impressions': 5}} (Count: 1)
#
# Column: estimated_audience_size
# Count: 1
# Mean: 75000.0
# Min: 75000.0
# Max: 75000.0
# Standard Deviation: 0.0
#
# Column: estimated_impressions
# Count: 1
# Mean: 22499.0
# Min: 22499.0
# Max: 22499.0
# Standard Deviation: 0.0
#
# Column: estimated_spend
# Count: 1
# Mean: 49.0
# Min: 49.0
# Max: 49.0
# Standard Deviation: 0.0
#
# Column: publisher_platforms
# Count: 1
# Unique Values: 1
# Most Frequent Value: ['facebook', 'instagram'] (Count: 1)
#
# Column: illuminating_scored_message
# Count: 1
# Unique Values: 1
# Most Frequent Value: dc522d5aa4f91c326d105ec4c482cf4b0c378161a6438a4c604061979c49f0dc (Count: 1)
#
# Column: illuminating_mentions
# Count: 1
# Unique Values: 1
# Most Frequent Value: ['Kamala Harris', 'Tim Walz'] (Count: 1)
#
# Column: scam_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: election_integrity_Truth_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: advocacy_msg_type_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: issue_msg_type_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: attack_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: image_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: cta_msg_type_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: engagement_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: fundraising_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: voting_cta_subtype_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: covid_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: economy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: education_topic_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: environment_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: foreign_policy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: governance_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: health_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: immigration_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: lgbtq_issues_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: military_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: race_and_ethnicity_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: safety_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: social_and_cultural_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: technology_and_privacy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: womens_issue_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: incivility_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: freefair_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: fraud_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Group: ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d')
#
# === Overall Statistics for 2024_fb_ads_president_scored_anon.csv - Group ('4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230', '07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d') ===
#
# Column: page_id
# Count: 1
# Unique Values: 1
# Most Frequent Value: 4ff23a48b53d988df50ddfebb0e442a984ab8f94e874ef9b9cb34394e0c5d230 (Count: 1)
#
# Column: ad_id
# Count: 1
# Unique Values: 1
# Most Frequent Value: 07b5aefc27e872e971f793e49aac38496fa62e484f3928e2b6a2b6e3e08cac8d (Count: 1)
#
# Column: ad_creation_time
# Count: 1
# Unique Values: 1
# Most Frequent Value: 2024-10-13 (Count: 1)
#
# Column: bylines
# Count: 1
# Unique Values: 1
# Most Frequent Value: Texas Organizing Project PAC (Count: 1)
#
# Column: currency
# Count: 1
# Unique Values: 1
# Most Frequent Value: USD (Count: 1)
#
# Column: delivery_by_region
# Count: 1
# Unique Values: 1
# Most Frequent Value: {'Texas': {'spend': 149, 'impressions': 32499}} (Count: 1)
#
# Column: demographic_distribution
# Count: 1
# Unique Values: 1
# Most Frequent Value: {'female_18-24': {'spend': 26, 'impressions': 5791}, 'male_45-54': {'spend': 7, 'impressions': 1573}, 'male_65+': {'spend': 1, 'impressions': 370}, 'female_65+': {'spend': 1, 'impressions': 298}, 'unknown_55-64': {'spend': 0, 'impressions': 9}, 'male_55-64': {'spend': 3, 'impressions': 790}, 'female_55-64': {'spend': 2, 'impressions': 578}, 'unknown_45-54': {'spend': 0, 'impressions': 21}, 'female_45-54': {'spend': 5, 'impressions': 1191}, 'male_18-24': {'spend': 19, 'impressions': 4285}, 'unknown_35-44': {'spend': 0, 'impressions': 27}, 'male_35-44': {'spend': 13, 'impressions': 2954}, 'female_35-44': {'spend': 11, 'impressions': 2531}, 'unknown_25-34': {'spend': 0, 'impressions': 37}, 'male_25-34': {'spend': 28, 'impressions': 6189}, 'female_25-34': {'spend': 26, 'impressions': 5750}, 'unknown_18-24': {'spend': 0, 'impressions': 87}, 'unknown_65+': {'spend': 0, 'impressions': 9}} (Count: 1)
#
# Column: estimated_audience_size
# Count: 1
# Mean: 75000.0
# Min: 75000.0
# Max: 75000.0
# Standard Deviation: 0.0
#
# Column: estimated_impressions
# Count: 1
# Mean: 32499.0
# Min: 32499.0
# Max: 32499.0
# Standard Deviation: 0.0
#
# Column: estimated_spend
# Count: 1
# Mean: 149.0
# Min: 149.0
# Max: 149.0
# Standard Deviation: 0.0
#
# Column: publisher_platforms
# Count: 1
# Unique Values: 1
# Most Frequent Value: ['facebook', 'instagram'] (Count: 1)
#
# Column: illuminating_scored_message
# Count: 1
# Unique Values: 1
# Most Frequent Value: 6dc61896f4a44cf4fdbe564604bbebe33b84d2dbfb8bacc761b345b2879f0804 (Count: 1)
#
# Column: illuminating_mentions
# Count: 1
# Unique Values: 1
# Most Frequent Value: ['Kamala Harris', 'Tim Walz'] (Count: 1)
#
# Column: scam_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: election_integrity_Truth_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: advocacy_msg_type_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: issue_msg_type_illuminating
# Count: 1
# Mean: 1.0
# Min: 1.0
# Max: 1.0
# Standard Deviation: 0.0
#
# Column: attack_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: image_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: cta_msg_type_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: engagement_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: fundraising_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: voting_cta_subtype_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: covid_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: economy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: education_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: environment_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: foreign_policy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: governance_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: health_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: immigration_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: lgbtq_issues_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: military_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: race_and_ethnicity_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: safety_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: social_and_cultural_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: technology_and_privacy_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: womens_issue_topic_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: incivility_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: freefair_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Column: fraud_illuminating
# Count: 1
# Mean: 0.0
# Min: 0.0
# Max: 0.0
# Standard Deviation: 0.0
#
# Loaded 19009 rows from 2024_fb_posts_president_scored_anon.csv
#
# === Overall Statistics for 2024_fb_posts_president_scored_anon.csv ===
#
# Column: Facebook_Id
# Count: 19009
# Unique Values: 21
# Most Frequent Value: 32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064 (Count: 9013)
#
# Column: post_id
# Count: 19009
# Unique Values: 19009
# Most Frequent Value: 8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138 (Count: 1)
#
# Column: Page Category
# Count: 16537
# Unique Values: 6
# Most Frequent Value: PERSON (Count: 9453)
#
# Column: Page Admin Top Country
# Count: 16280
# Unique Values: 1
# Most Frequent Value: US (Count: 16280)
#
# Column: Post Created
# Count: 19009
# Unique Values: 18951
# Most Frequent Value: 2023-11-14 11:11:44 EST (Count: 2)
#
# Column: Post Created Date
# Count: 19009
# Unique Values: 425
# Most Frequent Value: 2024-10-31 (Count: 103)
#
# Column: Post Created Time
# Count: 19009
# Unique Values: 16102
# Most Frequent Value: 19:42:00 (Count: 7)
#
# Column: Type
# Count: 16544
# Unique Values: 9
# Most Frequent Value: Link (Count: 7404)
#
# Column: Total Interactions
# Count: 19009
# Mean: 2210.154813168496
# Min: 0.0
# Max: 470087.0
# Standard Deviation: 13066.16858384993
#
# Column: Likes
# Count: 19009
# Mean: 2377.6954074385817
# Min: 0.0
# Max: 351979.0
# Standard Deviation: 11253.173660942826
#
# Column: Comments
# Count: 19009
# Mean: 901.583197432795
# Min: 0.0
# Max: 93872.0
# Standard Deviation: 3681.88324663012
#
# Column: Shares
# Count: 19009
# Mean: 320.53895523173236
# Min: 0.0
# Max: 76150.0
# Standard Deviation: 1722.114579655431
#
# Column: Love
# Count: 19009
# Mean: 413.87732126887266
# Min: 0.0
# Max: 244482.0
# Standard Deviation: 3730.8423123351736
#
# Column: Wow
# Count: 19009
# Mean: 5.8683255300120996
# Min: 0.0
# Max: 4345.0
# Standard Deviation: 52.94558592166891
#
# Column: Haha
# Count: 19009
# Mean: 105.71971171550318
# Min: 0.0
# Max: 99276.0
# Standard Deviation: 942.0094692245306
#
# Column: Sad
# Count: 19009
# Mean: 10.172181598190331
# Min: 0.0
# Max: 56111.0
# Standard Deviation: 418.3140035654345
#
# Column: Angry
# Count: 19009
# Mean: 20.05550002630333
# Min: 0.0
# Max: 11814.0
# Standard Deviation: 156.0159849366593
#
# Column: Care
# Count: 19009
# Mean: 34.92903361565574
# Min: 0.0
# Max: 85236.0
# Standard Deviation: 790.0824307109294
#
# Column: Video Share Status
# Count: 3271
# Unique Values: 3
# Most Frequent Value: owned (Count: 3100)
#
# Column: Is Video Owner?
# Count: 16544
# Unique Values: 3
# Most Frequent Value: - (Count: 13280)
#
# Column: Post Views
# Count: 16544
# Mean: 6485.058510638298
# Min: 0.0
# Max: 4276477.0
# Standard Deviation: 90390.2265080491
#
# Column: Total Views
# Count: 16544
# Mean: 7461.847014023211
# Min: 0.0
# Max: 4462155.0
# Standard Deviation: 95973.37816684529
#
# Column: Total Views For All Crossposts
# Count: 16544
# Mean: 3555.9379835589943
# Min: 0.0
# Max: 4499458.0
# Standard Deviation: 88091.3858618148
#
# Column: Video Length
# Count: 3271
# Unique Values: 774
# Most Frequent Value: 00:00:30 (Count: 83)
#
# Column: Sponsor Id
# Count: 0
# Unique Values: 0
# Most Frequent Value: N/A (Count: 0)
#
# Column: Sponsor Name
# Count: 0
# Unique Values: 0
# Most Frequent Value: N/A (Count: 0)
#
# Column: Sponsor Category
# Count: 0
# Unique Values: 0
# Most Frequent Value: N/A (Count: 0)
#
# Column: Overperforming Score
# Count: 16544
# Mean: -2.7441604206963373
# Min: -198.75
# Max: 246.78
# Standard Deviation: 7.808240961856569
#
# Column: illuminating_scored_messageelection_integrity_Truth_illuminating
# Count: 0
# Unique Values: 0
# Most Frequent Value: N/A (Count: 0)
#
# Column: advocacy_msg_type_illuminating
# Count: 19009
# Mean: 0.549266137092956
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.4975669278960663
#
# Column: issue_msg_type_illuminating
# Count: 19009
# Mean: 0.4603082750276185
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.498422077128119
#
# Column: attack_msg_type_illuminating
# Count: 19009
# Mean: 0.2166868325530012
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.41198743809875554
#
# Column: image_msg_type_illuminating
# Count: 19009
# Mean: 0.14856120784891366
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.3556554166202938
#
# Column: cta_msg_type_illuminating
# Count: 19009
# Mean: 0.1328318165079699
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.3393928771072356
#
# Column: engagement_cta_subtype_illuminating
# Count: 19009
# Mean: 0.0908517018254511
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.2873981038575075
#
# Column: fundraising_cta_subtype_illuminating
# Count: 19009
# Mean: 0.01841233100110474
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.1344370375611009
#
# Column: voting_cta_subtype_illuminating
# Count: 19009
# Mean: 0.023409963701404597
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.15120164450463816
#
# Column: covid_topic_illuminating
# Count: 19009
# Mean: 0.05239623336314377
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.2228247474867119
#
# Column: economy_topic_illuminating
# Count: 19009
# Mean: 0.09037824188542269
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.28672288935333456
#
# Column: education_topic_illuminating
# Count: 19009
# Mean: 0.014992898100899574
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.1215241173900813
#
# Column: environment_topic_illuminating
# Count: 19009
# Mean: 0.022252617181335158
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.14750402777519722
#
# Column: foreign_policy_topic_illuminating
# Count: 19009
# Mean: 0.03687726866221264
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.1884604354187676
#
# Column: governance_topic_illuminating
# Count: 19009
# Mean: 0.03109053606186543
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.1735624228606407
#
# Column: health_topic_illuminating
# Count: 19009
# Mean: 0.04866116050291967
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.21515866694470906
#
# Column: immigration_topic_illuminating
# Count: 19009
# Mean: 0.04082276816244937
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.19787943238754
#
# Column: lgbtq_issues_topic_illuminating
# Count: 19009
# Mean: 0.0033668262402020096
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.057926597701494234
#
# Column: military_topic_illuminating
# Count: 19009
# Mean: 0.0055763059603345785
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.07446617199890898
#
# Column: race_and_ethnicity_topic_illuminating
# Count: 19009
# Mean: 0.021568730601294123
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.14527050788629303
#
# Column: safety_topic_illuminating
# Count: 19009
# Mean: 0.032195275921931714
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.1765183846805988
#
# Column: social_and_cultural_topic_illuminating
# Count: 19009
# Mean: 0.06170761218370246
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.2406237369469409
#
# Column: technology_and_privacy_topic_illuminating
# Count: 19009
# Mean: 0.0020516597401230995
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.04524876166741346
#
# Column: womens_issue_topic_illuminating
# Count: 19009
# Mean: 0.0254616234415277
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.15752247196272268
#
# Column: incivility_illuminating
# Count: 19009
# Mean: 0.1278867904676732
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.33396370954273136
#
# Column: scam_illuminating
# Count: 18060
# Mean: 0.020210409745293468
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.14071939838991823
#
# Column: freefair_illuminating
# Count: 19009
# Mean: 0.0028407596401704457
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.05322301874974824
#
# Column: fraud_illuminating
# Count: 19009
# Mean: 0.00862749224051765
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.09248274767845381
# No grouping columns ('page_id', 'ad_id', 'state') found in 2024_fb_posts_president_scored_anon.csv.
#
# Loaded 27304 rows from 2024_tw_posts_president_scored_anon.csv
#
# === Overall Statistics for 2024_tw_posts_president_scored_anon.csv ===
#
# Column: id
# Count: 27304
# Unique Values: 27304
# Most Frequent Value: cc46051622b8a9c1b883a3bbf12c640b12ac1cbdc7f48a773b6cc2a65f03aa2d (Count: 1)
#
# Column: url
# Count: 27304
# Unique Values: 27304
# Most Frequent Value: f70a206472e9deaf6e313297c1efb891729ced346a0aeb34e16935d78f74b937 (Count: 1)
#
# Column: source
# Count: 27304
# Unique Values: 14
# Most Frequent Value: Twitter Web App (Count: 14930)
#
# Column: retweetCount
# Count: 27304
# Mean: 1322.0551933782597
# Min: 0.0
# Max: 144615.0
# Standard Deviation: 3404.9418860146216
#
# Column: replyCount
# Count: 27304
# Mean: 1063.7850131848813
# Min: 0.0
# Max: 121270.0
# Standard Deviation: 3174.9235122786986
#
# Column: likeCount
# Count: 27304
# Mean: 6913.69282888954
# Min: 0.0
# Max: 915221.0
# Standard Deviation: 21589.91261663252
#
# Column: quoteCount
# Count: 27304
# Mean: 128.08156314093173
# Min: 0.0
# Max: 123320.0
# Standard Deviation: 1131.5127467920652
#
# Column: viewCount
# Count: 27304
# Mean: 507084.7318341635
# Min: 5.0
# Max: 333502775.0
# Standard Deviation: 3212115.1633513304
#
# Column: createdAt
# Count: 27304
# Unique Values: 27014
# Most Frequent Value: 2023-10-06 04:55:21 (Count: 4)
#
# Column: lang
# Count: 27304
# Unique Values: 12
# Most Frequent Value: en (Count: 27281)
#
# Column: bookmarkCount
# Count: 27304
# Mean: 136.21352182830356
# Min: 0.0
# Max: 42693.0
# Standard Deviation: 712.5672453544687
#
# Column: isReply
# Count: 27304
# Unique Values: 2
# Most Frequent Value: False (Count: 23930)
#
# Column: isRetweet
# Count: 27304
# Unique Values: 1
# Most Frequent Value: False (Count: 27304)
#
# Column: isQuote
# Count: 27304
# Unique Values: 2
# Most Frequent Value: False (Count: 24064)
#
# Column: isConversationControlled
# Count: 27304
# Unique Values: 2
# Most Frequent Value: False (Count: 27296)
#
# Column: quoteId
# Count: 3287
# Mean: 1.7642983966589228e+18
# Min: 7.912639390153769e+17
# Max: 1.8535761683325583e+18
# Standard Deviation: 6.893637788495935e+16
#
# Column: inReplyToId
# Count: 3345
# Mean: 1.7582857247419858e+18
# Min: 1.2400673584227e+18
# Max: 1.853530653414859e+18
# Standard Deviation: 4.3605446235839016e+16
#
# Column: month_year
# Count: 27304
# Unique Values: 15
# Most Frequent Value: 2024-10 (Count: 3586)
#
# Column: illuminating_scored_message
# Count: 27304
# Unique Values: 27136
# Most Frequent Value: 36cb7d55fcf85362ca03f624c2f574f1f55f89db559b17da084df6e643afe5cd (Count: 21)
#
# Column: election_integrity_Truth_illuminating
# Count: 26034
# Mean: 0.03714373511561804
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.1891139287765119
#
# Column: advocacy_msg_type_illuminating
# Count: 26034
# Mean: 0.5636859491434278
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.4959275147455164
#
# Column: issue_msg_type_illuminating
# Count: 26034
# Mean: 0.507682261657832
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.4999409793724566
#
# Column: attack_msg_type_illuminating
# Count: 26034
# Mean: 0.3075977567795959
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.46149905395768714
#
# Column: image_msg_type_illuminating
# Count: 26034
# Mean: 0.22643466236460014
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.41852360273277145
#
# Column: cta_msg_type_illuminating
# Count: 26034
# Mean: 0.10966428516555274
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.3124708461995961
#
# Column: engagement_cta_subtype_illuminating
# Count: 26034
# Mean: 0.0669124990397173
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.24987039943127815
#
# Column: fundraising_cta_subtype_illuminating
# Count: 26034
# Mean: 0.007874318199277867
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.08838729157616787
#
# Column: voting_cta_subtype_illuminating
# Count: 26034
# Mean: 0.016785741722363065
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.12846781930581222
#
# Column: covid_topic_illuminating
# Count: 26034
# Mean: 0.0076054390412537455
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.08687690336470884
#
# Column: economy_topic_illuminating
# Count: 26034
# Mean: 0.16021356687408772
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.3668040074257861
#
# Column: education_topic_illuminating
# Count: 26034
# Mean: 0.01843742797879696
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.13452690893766167
#
# Column: environment_topic_illuminating
# Count: 26034
# Mean: 0.028539602058846123
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.16650853783869715
#
# Column: foreign_policy_topic_illuminating
# Count: 26034
# Mean: 0.042252439118076364
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.20116453590698016
#
# Column: governance_topic_illuminating
# Count: 26034
# Mean: 0.022969962356917877
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.14980768734028893
#
# Column: health_topic_illuminating
# Count: 26034
# Mean: 0.05565798571099332
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.2292600583128232
#
# Column: immigration_topic_illuminating
# Count: 26034
# Mean: 0.06529922409157256
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.24705310243871123
#
# Column: lgbtq_issues_topic_illuminating
# Count: 26034
# Mean: 0.0030729046631328264
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.055348549394396096
#
# Column: military_topic_illuminating
# Count: 26034
# Mean: 0.010985634170699855
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.10423507093375506
#
# Column: race_and_ethnicity_topic_illuminating
# Count: 26034
# Mean: 0.015402934623953292
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.12314903259430217
#
# Column: safety_topic_illuminating
# Count: 26034
# Mean: 0.03760467081508796
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.19023816532961207
#
# Column: social_and_cultural_topic_illuminating
# Count: 26034
# Mean: 0.05197050011523392
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.2219674913878064
#
# Column: technology_and_privacy_topic_illuminating
# Count: 26034
# Mean: 0.0020357993393254974
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.04507388224211153
#
# Column: womens_issue_topic_illuminating
# Count: 26034
# Mean: 0.02331566413152032
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.15090408853842874
#
# Column: incivility_illuminating
# Count: 26034
# Mean: 0.17857417223630637
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.38299534885748604
#
# Column: scam_illuminating
# Count: 26034
# Mean: 0.012368441269109626
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.11052358540005695
#
# Column: freefair_illuminating
# Count: 27304
# Mean: 0.0014283621447406974
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.03776667745942233
#
# Column: fraud_illuminating
# Count: 27304
# Mean: 0.0027468502783474947
# Min: 0.0
# Max: 1.0
# Standard Deviation: 0.0523383711238166
# No grouping columns ('page_id', 'ad_id', 'state') found in 2024_tw_posts_president_scored_anon.csv.
